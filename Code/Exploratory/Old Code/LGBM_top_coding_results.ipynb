# %%
import pandas as pd
import numpy as np

from sktime.performance_metrics.forecasting import mean_absolute_error

# nice time series plots
from sktime.utils.plotting import plot_series

# %%
full_data = pd.read_csv("../../Data/Train/Clean/full_m3_monthly_micro_clean.csv", header=None, skiprows=1)
# convert to a list of series, potentially with different lengths
full_data = [x.dropna() for _, x in full_data.iterrows()]
test = pd.read_csv("../../Outputs/Forecasts/Test_h1.csv")
orig_fcasts = pd.read_csv("../../Outputs/Forecasts/Multivariate_LGBM_h1_original.csv")
protected_fcasts = pd.read_csv("../../Outputs/Forecasts/Multivariate_LGBM_h1_Top_0.1.csv")

# %%
protected_fcasts
# Out:
#              0            1            2            3            4  \
# 0  1227.158301  1301.026847  4767.903934  7141.657615  9984.724864
#
#              5            6            7            8            9  ...  \
# 0  1326.579854  4990.988417  4437.245217  2443.609395  4423.746923  ...
#
#            464         465          466          467         468          469  \
# 0  2811.329099  4614.14159  5496.737043  7412.903571  5113.28668  8365.239213
#
#            470         471          472          473
# 0  5139.170065  4558.29046  8224.399938  2688.879379
#
# [1 rows x 474 columns]

# %%
orig_maes = mean_absolute_error(test, orig_fcasts, multioutput="raw_values")

# %%
protected_maes = mean_absolute_error(test, protected_fcasts, multioutput="raw_values")

# %%
np.argsort(orig_maes - protected_maes)
# Out:
# array([432, 435,  29, 263,  69, 223, 236, 210, 103,  59, 150, 430, 389,
#        426,  13, 397, 268,  68,  53,  65, 243, 164, 469,  55, 434, 264,
#         71,  20, 153, 185, 395, 187, 225, 145, 203,  36,  12, 340, 418,
#        391, 157, 224, 401,   9,  82, 336,  52, 270, 317, 128,  67, 339,
#          5,  14,  51,  85, 258, 237, 381, 388, 462,  83, 343, 289,  72,
#        385, 448, 256, 206, 403, 218,  80, 338, 294,  41, 281, 290,  18,
#        116,  94, 399, 416, 186, 271, 219, 356,  75, 131, 120, 369, 465,
#        167,  31, 332, 460, 231,  66, 408, 122, 272, 337, 105,  22, 302,
#        363, 392, 300,   1, 248, 201, 425,  99,  64, 209, 467,   6, 136,
#         44, 140, 441, 330, 411, 291, 242, 250, 350, 182, 453, 335, 409,
#         91, 331,  39, 376, 428, 251, 141, 353, 342,  47, 197, 262, 298,
#         84, 373, 398, 273,  98,  26, 345, 380,  79, 191,  95,  78, 433,
#        133, 473,   2, 134, 457, 451, 387, 239, 455, 288, 245, 280, 323,
# ...

# %%
np.sort(orig_maes - protected_maes)
# Out:
# array([-2.16862330e+03, -1.77472939e+03, -9.85548322e+02, -9.48363555e+02,
#        -8.23770189e+02, -7.98627720e+02, -6.88463917e+02, -6.52568312e+02,
#        -5.15602717e+02, -4.69193342e+02, -4.38139943e+02, -4.31045432e+02,
#        -4.20472913e+02, -4.13330342e+02, -3.92901451e+02, -3.86891442e+02,
#        -3.84998747e+02, -3.64696616e+02, -3.61915589e+02, -3.56824304e+02,
#        -3.48044587e+02, -3.42648779e+02, -3.42440957e+02, -3.35589162e+02,
#        -3.27402634e+02, -3.25161816e+02, -3.06525825e+02, -2.92750017e+02,
#        -2.89456512e+02, -2.84134139e+02, -2.80622388e+02, -2.74592515e+02,
#        -2.70616494e+02, -2.69714465e+02, -2.66208692e+02, -2.64453667e+02,
#        -2.58410855e+02, -2.58206026e+02, -2.53740456e+02, -2.46919522e+02,
#        -2.46117114e+02, -2.43989369e+02, -2.36629533e+02, -2.31923058e+02,
#        -2.27150559e+02, -2.24601662e+02, -2.19921187e+02, -2.12396588e+02,
# ...

# %%
np.max(orig_maes)-np.min(orig_maes)
# Out:
# 9640.882596605272

# %%
np.max(protected_maes) - np.min(protected_maes)
# Out:
# 9464.191256280865

# %%
plot_series(full_data[438], orig_fcasts.iloc[:,438], protected_fcasts.iloc[:,438], labels = ["series", "original", "protected"])
# Out:
# (<Figure size 1152x288 with 1 Axes>, <AxesSubplot:ylabel='438'>)

# %%
plot_series(full_data[86], orig_fcasts.iloc[:,86], protected_fcasts.iloc[:,86], labels = ["series", "original", "protected"])
# Out:
# (<Figure size 1152x288 with 1 Axes>, <AxesSubplot:ylabel='86'>)

# %%
plot_series(full_data[60], orig_fcasts.iloc[:,60], protected_fcasts.iloc[:,60], labels = ["series", "original", "protected"])
# Out:
# (<Figure size 1152x288 with 1 Axes>, <AxesSubplot:ylabel='60'>)

# %%
plot_series(full_data[215], orig_fcasts.iloc[:,215], protected_fcasts.iloc[:,215], labels = ["series", "original", "protected"])
# Out:
# (<Figure size 1152x288 with 1 Axes>, <AxesSubplot:ylabel='215'>)

# %%
plot_series(full_data[163], orig_fcasts.iloc[:,163], protected_fcasts.iloc[:,163], labels = ["series", "original", "protected"])
# Out:
# (<Figure size 1152x288 with 1 Axes>, <AxesSubplot:ylabel='163'>)
