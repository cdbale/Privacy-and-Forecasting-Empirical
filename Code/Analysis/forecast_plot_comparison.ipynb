# %%
import numpy as np
import pandas as pd

# nice time series plots
from sktime.utils.plotting import plot_series

# %% [markdown]
# ***

# %%
ses_dp = pd.read_csv("../../Outputs/Forecasts/SES_h18_DP_0.1.csv")
rnn_dp = pd.read_csv("../../Outputs/Forecasts/RNN_h18_DP_0.1.csv")
tes_dp = pd.read_csv("../../Outputs/Forecasts/TES_h18_DP_0.1.csv")
full_data = pd.read_csv("../../Data/Train/Clean/full_m3_monthly_micro_clean.csv")
dp_data = pd.read_csv("../../Data/Train/Clean/protected_m3_monthly_micro_h18_DP_0.1.csv")

# %%
# convert to a list of series, potentially with different lengths
full_data = [x.dropna() for _, x in full_data.iterrows()]
dp_data = [x.dropna() for _, x in dp_data.iterrows()]

# %%
series_num = 5

# %%
orig = full_data[series_num]
orig.index = np.arange(0, len(temp))

protected = dp_data[series_num]
protected.index = np.arange(0, len(protected))

ses = ses_dp.iloc[:,series_num]
ses.index = np.arange(len(protected), len(protected)+18)

tes = tes_dp.iloc[:,series_num]
tes.index = np.arange(len(protected), len(protected)+18)

rnn = rnn_dp.iloc[:,series_num]
rnn.index = np.arange(len(protected), len(protected)+18)

# %%
plot_series(orig, protected, ses, rnn, tes)
# Out:
# (<Figure size 1152x288 with 1 Axes>, <AxesSubplot:ylabel='5'>)

# %%
plot_series(ses, rnn, tes, labels=["SES", "RNN", "TES"])
# Out:
# (<Figure size 1152x288 with 1 Axes>, <AxesSubplot:ylabel='5'>)

# %%
plot_series(ses, rnn, labels=["SES", "RNN"])
# Out:
# (<Figure size 1152x288 with 1 Axes>, <AxesSubplot:ylabel='5'>)
