# %% [markdown]
# ## Analyzing the Effects of Top/Bottom Coding on The Accuracy of Global LGBM Forecasts

# %% [markdown]
# ***

# %% [markdown]
# ## Import Modules

# %%
# general modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# light gradient boosting model package
import lightgbm as lgb

##### the `helper_functions.py` file contains many custom functions we wrote to aid in our analysis
##### `full_coding_analysis` combines all of the following - train-test split data,
##### data protection, train models, compare accuracies, return accuracy results
from helper_functions import full_coding_analysis
from helper_functions import *

# import detrender and deseasonalizer
from sktime.transformations.series.detrend import Detrender
# nice time series plots
from sktime.utils.plotting import plot_series

# %% [markdown]
# ## Import data

# %%
# import weekly finance time series
Y = np.genfromtxt("../../Data/Train/Clean/weekly_finance_clean.csv", delimiter = ',', skip_header = 1)
Y = pd.DataFrame(Y)

# %% [markdown]
# This file experiments with applying top and bottom coding to detrended data (intuition suggests this type of data is a better candidate for this type of protection than the original finance series data) so we remove the trend from the finance data here.

# %%
# detrender = Detrender()
# detrended_series = [detrender.fit_transform(series) for _ , series in Y.iterrows()]
# detrended_series = [i+np.abs(np.min(i))+1.0 for i in detrended_series]
# Y = pd.concat(detrended_series, axis=1).T

# %% [markdown]
# ***

# %% [markdown]
# We obtain results for a combination of forecast horizons, coding types (top and bottom), coding percentages, and model complexities:
#
# * Forecast Horizons: (1, 5, 15)
# * Coding Types: (Top, Bottom)
# * Coding Percentages: (0.10, 0.20, 0.40)
# * Model complexities (window length): (10, 20, 40)

# %% [markdown]
# ## Simple Model (window length = 10)

# %%
forecaster = lgb.LGBMRegressor()
window_length = 10

# %%
results_dict_10 = {}
fcasts_10 = {}
fcasts_protected_10 = {}
tests = {}
types = ["Top", "Bottom"]
percentages = [0.10, 0.20, 0.40]
horizons = [1, 20]

# %%
for t in types:
    for p in percentages:
        for h in horizons:
            idx = "h="+str(h)+", "+t+" "+str(p)
            results_dict_10[idx], tests[idx], fcasts_10[idx], fcasts_protected_10[idx] = full_coding_analysis(time_series_data=Y,
                                                                                                              forecasting_model=forecaster,
                                                                                                              forecast_horizon=h, 
                                                                                                              coding_type=t, 
                                                                                                              coding_percentage=p, 
                                                                                                              window_length=window_length)

# %%
results_dict_10
# Out:
# {'h=1, Top 0.1': {'Mean Accuracies': array([67.4396, 67.4396]),
#   'Protected Mean Accuracies:': array([112.4631, 112.4631]),
#   '% Change Mean accuracy:': array([-0.6676, -0.6676]),
#   '% Change Median accuracy:': array([-1.2035, -1.2035]),
#   '% Forecasted Points adjusted downward:': 0.6829,
#   '% Forecasted Points adjusted upward:': 0.3171,
#   '% Series with improved accuracy:': array([0.3354, 0.3354]),
#   '% Series with reduced accuracy:': array([0.6646, 0.6646]),
#   'Original Mean Absolute Error Upward Adjusted:': 118.0343,
#   'Original Mean Absolute Error Downward Adjusted:': 43.9492,
#   'Protected Mean Absolute Error Upward Adjusted:': 110.2835,
#   'Protected Mean Absolute Error Downward Adjusted:': 113.4751},
#  'h=20, Top 0.1': {'Mean Accuracies': array([115.1224, 138.0561]),
#   'Protected Mean Accuracies:': array([134.0747, 155.5238]),
#   '% Change Mean accuracy:': array([-0.1646, -0.1265]),
#   '% Change Median accuracy:': array([-0.0703, -0.0654]),
#   '% Forecasted Points adjusted downward:': 0.7829,
#   '% Forecasted Points adjusted upward:': 0.2171,
#   '% Series with improved accuracy:': array([0.311 , 0.3415]),
#   '% Series with reduced accuracy:': array([0.689 , 0.6585]),
#   'Original Mean Absolute Error Upward Adjusted:': 115.1892,
#   'Original Mean Absolute Error Downward Adjusted:': 115.1039,
#   'Protected Mean Absolute Error Upward Adjusted:': 116.9253,
#   'Protected Mean Absolute Error Downward Adjusted:': 138.8295},
#  'h=1, Top 0.2': {'Mean Accuracies': array([67.4396, 67.4396]),
#   'Protected Mean Accuracies:': array([159.9393, 159.9393]),
#   '% Change Mean accuracy:': array([-1.3716, -1.3716]),
#   '% Change Median accuracy:': array([-2.406, -2.406]),
#   '% Forecasted Points adjusted downward:': 0.7378,
#   '% Forecasted Points adjusted upward:': 0.2622,
#   '% Series with improved accuracy:': array([0.3232, 0.3232]),
#   '% Series with reduced accuracy:': array([0.6768, 0.6768]),
#   'Original Mean Absolute Error Upward Adjusted:': 143.9859,
#   'Original Mean Absolute Error Downward Adjusted:': 40.2372,
#   'Protected Mean Absolute Error Upward Adjusted:': 121.9761,
#   'Protected Mean Absolute Error Downward Adjusted:': 173.4303},
#  'h=20, Top 0.2': {'Mean Accuracies': array([115.1224, 138.0561]),
#   'Protected Mean Accuracies:': array([175.2238, 196.4458]),
#   '% Change Mean accuracy:': array([-0.5221, -0.4229]),
#   '% Change Median accuracy:': array([-0.4406, -0.3809]),
#   '% Forecasted Points adjusted downward:': 0.7799,
#   '% Forecasted Points adjusted upward:': 0.2201,
#   '% Series with improved accuracy:': array([0.2683, 0.2866]),
#   '% Series with reduced accuracy:': array([0.7317, 0.7134]),
#   'Original Mean Absolute Error Upward Adjusted:': 130.9947,
#   'Original Mean Absolute Error Downward Adjusted:': 110.6424,
#   'Protected Mean Absolute Error Upward Adjusted:': 126.8109,
#   'Protected Mean Absolute Error Downward Adjusted:': 188.8884},
#  'h=1, Top 0.4': {'Mean Accuracies': array([67.4396, 67.4396]),
#   'Protected Mean Accuracies:': array([285.1235, 285.1235]),
#   '% Change Mean accuracy:': array([-3.2278, -3.2278]),
#   '% Change Median accuracy:': array([-4.5979, -4.5979]),
#   '% Forecasted Points adjusted downward:': 0.811,
#   '% Forecasted Points adjusted upward:': 0.189,
#   '% Series with improved accuracy:': array([0.2439, 0.2439]),
#   '% Series with reduced accuracy:': array([0.7561, 0.7561]),
#   'Original Mean Absolute Error Upward Adjusted:': 183.9357,
#   'Original Mean Absolute Error Downward Adjusted:': 40.2864,
#   'Protected Mean Absolute Error Upward Adjusted:': 140.3404,
#   'Protected Mean Absolute Error Downward Adjusted:': 318.87},
#  'h=20, Top 0.4': {'Mean Accuracies': array([115.1224, 138.0561]),
#   'Protected Mean Accuracies:': array([288.4714, 308.1325]),
#   '% Change Mean accuracy:': array([-1.5058, -1.2319]),
#   '% Change Median accuracy:': array([-1.2277, -1.103 ]),
#   '% Forecasted Points adjusted downward:': 0.7954,
#   '% Forecasted Points adjusted upward:': 0.2046,
#   '% Series with improved accuracy:': array([0.2012, 0.2195]),
#   '% Series with reduced accuracy:': array([0.7988, 0.7805]),
#   'Original Mean Absolute Error Upward Adjusted:': 152.2669,
#   'Original Mean Absolute Error Downward Adjusted:': 105.5694,
#   'Protected Mean Absolute Error Upward Adjusted:': 171.9445,
#   'Protected Mean Absolute Error Downward Adjusted:': 318.4406},
#  'h=1, Bottom 0.1': {'Mean Accuracies': array([67.4396, 67.4396]),
#   'Protected Mean Accuracies:': array([78.0371, 78.0371]),
#   '% Change Mean accuracy:': array([-0.1571, -0.1571]),
#   '% Change Median accuracy:': array([-0.0794, -0.0794]),
#   '% Forecasted Points adjusted downward:': 0.4085,
#   '% Forecasted Points adjusted upward:': 0.5915,
#   '% Series with improved accuracy:': array([0.4878, 0.4878]),
#   '% Series with reduced accuracy:': array([0.5122, 0.5122]),
#   'Original Mean Absolute Error Upward Adjusted:': 83.961,
#   'Original Mean Absolute Error Downward Adjusted:': 43.5205,
#   'Protected Mean Absolute Error Upward Adjusted:': 99.1395,
#   'Protected Mean Absolute Error Downward Adjusted:': 47.486},
#  'h=20, Bottom 0.1': {'Mean Accuracies': array([115.1224, 138.0561]),
#   'Protected Mean Accuracies:': array([121.7905, 142.6407]),
#   '% Change Mean accuracy:': array([-0.0579, -0.0332]),
#   '% Change Median accuracy:': array([ 0.0447, -0.0071]),
#   '% Forecasted Points adjusted downward:': 0.5402,
#   '% Forecasted Points adjusted upward:': 0.4598,
#   '% Series with improved accuracy:': array([0.5183, 0.5244]),
#   '% Series with reduced accuracy:': array([0.4817, 0.4756]),
#   'Original Mean Absolute Error Upward Adjusted:': 131.3729,
#   'Original Mean Absolute Error Downward Adjusted:': 101.293,
#   'Protected Mean Absolute Error Upward Adjusted:': 140.0394,
#   'Protected Mean Absolute Error Downward Adjusted:': 106.2603},
#  'h=1, Bottom 0.2': {'Mean Accuracies': array([67.4396, 67.4396]),
#   'Protected Mean Accuracies:': array([98.0813, 98.0813]),
#   '% Change Mean accuracy:': array([-0.4544, -0.4544]),
#   '% Change Median accuracy:': array([-0.1141, -0.1141]),
#   '% Forecasted Points adjusted downward:': 0.4512,
#   '% Forecasted Points adjusted upward:': 0.5488,
#   '% Series with improved accuracy:': array([0.4756, 0.4756]),
#   '% Series with reduced accuracy:': array([0.5244, 0.5244]),
#   'Original Mean Absolute Error Upward Adjusted:': 92.0227,
#   'Original Mean Absolute Error Downward Adjusted:': 37.5412,
#   'Protected Mean Absolute Error Upward Adjusted:': 143.1218,
#   'Protected Mean Absolute Error Downward Adjusted:': 43.3024},
#  'h=20, Bottom 0.2': {'Mean Accuracies': array([115.1224, 138.0561]),
#   'Protected Mean Accuracies:': array([143.1876, 163.4131]),
#   '% Change Mean accuracy:': array([-0.2438, -0.1837]),
#   '% Change Median accuracy:': array([0.022 , 0.0227]),
#   '% Forecasted Points adjusted downward:': 0.6085,
#   '% Forecasted Points adjusted upward:': 0.3915,
#   '% Series with improved accuracy:': array([0.4634, 0.4817]),
#   '% Series with reduced accuracy:': array([0.5366, 0.5183]),
#   'Original Mean Absolute Error Upward Adjusted:': 128.6165,
#   'Original Mean Absolute Error Downward Adjusted:': 106.4419,
#   'Protected Mean Absolute Error Upward Adjusted:': 199.0743,
#   'Protected Mean Absolute Error Downward Adjusted:': 107.2364},
#  'h=1, Bottom 0.4': {'Mean Accuracies': array([67.4396, 67.4396]),
#   'Protected Mean Accuracies:': array([159.8457, 159.8457]),
#   '% Change Mean accuracy:': array([-1.3702, -1.3702]),
#   '% Change Median accuracy:': array([-0.1404, -0.1404]),
#   '% Forecasted Points adjusted downward:': 0.4512,
#   '% Forecasted Points adjusted upward:': 0.5488,
#   '% Series with improved accuracy:': array([0.4695, 0.4695]),
#   '% Series with reduced accuracy:': array([0.5305, 0.5305]),
#   'Original Mean Absolute Error Upward Adjusted:': 85.8293,
#   'Original Mean Absolute Error Downward Adjusted:': 45.0737,
#   'Protected Mean Absolute Error Upward Adjusted:': 250.1027,
#   'Protected Mean Absolute Error Downward Adjusted:': 50.0738},
#  'h=20, Bottom 0.4': {'Mean Accuracies': array([115.1224, 138.0561]),
#   'Protected Mean Accuracies:': array([215.4222, 234.7667]),
#   '% Change Mean accuracy:': array([-0.8712, -0.7005]),
#   '% Change Median accuracy:': array([-0.0359, -0.0356]),
#   '% Forecasted Points adjusted downward:': 0.6152,
#   '% Forecasted Points adjusted upward:': 0.3848,
#   '% Series with improved accuracy:': array([0.378 , 0.3902]),
#   '% Series with reduced accuracy:': array([0.622 , 0.6098]),
#   'Original Mean Absolute Error Upward Adjusted:': 131.0438,
#   'Original Mean Absolute Error Downward Adjusted:': 105.1656,
#   'Protected Mean Absolute Error Upward Adjusted:': 380.6053,
#   'Protected Mean Absolute Error Downward Adjusted:': 112.1214}}

# %% [markdown]
# ***
# ***

# %% [markdown]
# ## 'Medium' Model (window length = 20)

# %%
forecaster = lgb.LGBMRegressor()
window_length = 20

# %%
results_dict_20 = {}
fcasts_20 = {}
fcasts_protected_20 = {}
tests = {}
types = ["Top", "Bottom"]
percentages = [0.10, 0.20, 0.40]
horizons = [1, 20]

# %%
for t in types:
    for p in percentages:
        for h in horizons:
            idx = "h="+str(h)+", "+t+" "+str(p)
            results_dict_20[idx], tests[idx], fcasts_20[idx], fcasts_protected_20[idx] = full_coding_analysis(time_series_data=Y,
                                                                                                              forecasting_model=forecaster,
                                                                                                              forecast_horizon=h, 
                                                                                                              coding_type=t, 
                                                                                                              coding_percentage=p, 
                                                                                                              window_length=window_length)

# %%
results_dict_20
# Out:
# {'h=1, Top 0.1': {'Mean Accuracies': array([64.9424, 64.9424]),
#   'Protected Mean Accuracies:': array([105.4467, 105.4467]),
#   '% Change Mean accuracy:': array([-0.6237, -0.6237]),
#   '% Change Median accuracy:': array([-1.1011, -1.1011]),
#   '% Forecasted Points adjusted downward:': 0.689,
#   '% Forecasted Points adjusted upward:': 0.311,
#   '% Series with improved accuracy:': array([0.372, 0.372]),
#   '% Series with reduced accuracy:': array([0.628, 0.628]),
#   'Original Mean Absolute Error Upward Adjusted:': 93.0727,
#   'Original Mean Absolute Error Downward Adjusted:': 52.2464,
#   'Protected Mean Absolute Error Upward Adjusted:': 84.1944,
#   'Protected Mean Absolute Error Downward Adjusted:': 115.0384},
#  'h=20, Top 0.1': {'Mean Accuracies': array([125.6744, 149.4553]),
#   'Protected Mean Accuracies:': array([146.8518, 169.8595]),
#   '% Change Mean accuracy:': array([-0.1685, -0.1365]),
#   '% Change Median accuracy:': array([-0.036 , -0.0328]),
#   '% Forecasted Points adjusted downward:': 0.7381,
#   '% Forecasted Points adjusted upward:': 0.2619,
#   '% Series with improved accuracy:': array([0.3537, 0.3841]),
#   '% Series with reduced accuracy:': array([0.6463, 0.6159]),
#   'Original Mean Absolute Error Upward Adjusted:': 127.1728,
#   'Original Mean Absolute Error Downward Adjusted:': 125.1428,
#   'Protected Mean Absolute Error Upward Adjusted:': 140.698,
#   'Protected Mean Absolute Error Downward Adjusted:': 149.0353},
#  'h=1, Top 0.2': {'Mean Accuracies': array([64.9424, 64.9424]),
#   'Protected Mean Accuracies:': array([163.1015, 163.1015]),
#   '% Change Mean accuracy:': array([-1.5115, -1.5115]),
#   '% Change Median accuracy:': array([-2.3358, -2.3358]),
#   '% Forecasted Points adjusted downward:': 0.7378,
#   '% Forecasted Points adjusted upward:': 0.2622,
#   '% Series with improved accuracy:': array([0.2866, 0.2866]),
#   '% Series with reduced accuracy:': array([0.7134, 0.7134]),
#   'Original Mean Absolute Error Upward Adjusted:': 74.921,
#   'Original Mean Absolute Error Downward Adjusted:': 61.3962,
#   'Protected Mean Absolute Error Upward Adjusted:': 69.9338,
#   'Protected Mean Absolute Error Downward Adjusted:': 196.2107},
#  'h=20, Top 0.2': {'Mean Accuracies': array([125.6744, 149.4553]),
#   'Protected Mean Accuracies:': array([184.6465, 207.8935]),
#   '% Change Mean accuracy:': array([-0.4692, -0.391 ]),
#   '% Change Median accuracy:': array([-0.3788, -0.2555]),
#   '% Forecasted Points adjusted downward:': 0.746,
#   '% Forecasted Points adjusted upward:': 0.254,
#   '% Series with improved accuracy:': array([0.2744, 0.2866]),
#   '% Series with reduced accuracy:': array([0.7256, 0.7134]),
#   'Original Mean Absolute Error Upward Adjusted:': 146.0542,
#   'Original Mean Absolute Error Downward Adjusted:': 118.7368,
#   'Protected Mean Absolute Error Upward Adjusted:': 183.6415,
#   'Protected Mean Absolute Error Downward Adjusted:': 184.9886},
#  'h=1, Top 0.4': {'Mean Accuracies': array([64.9424, 64.9424]),
#   'Protected Mean Accuracies:': array([289.0875, 289.0875]),
#   '% Change Mean accuracy:': array([-3.4514, -3.4514]),
#   '% Change Median accuracy:': array([-4.1345, -4.1345]),
#   '% Forecasted Points adjusted downward:': 0.7927,
#   '% Forecasted Points adjusted upward:': 0.2073,
#   '% Series with improved accuracy:': array([0.2317, 0.2317]),
#   '% Series with reduced accuracy:': array([0.7683, 0.7683]),
#   'Original Mean Absolute Error Upward Adjusted:': 81.3246,
#   'Original Mean Absolute Error Downward Adjusted:': 60.6578,
#   'Protected Mean Absolute Error Upward Adjusted:': 70.8763,
#   'Protected Mean Absolute Error Downward Adjusted:': 346.1582},
#  'h=20, Top 0.4': {'Mean Accuracies': array([125.6744, 149.4553]),
#   'Protected Mean Accuracies:': array([287.1076, 306.5647]),
#   '% Change Mean accuracy:': array([-1.2845, -1.0512]),
#   '% Change Median accuracy:': array([-1.0813, -0.9059]),
#   '% Forecasted Points adjusted downward:': 0.8165,
#   '% Forecasted Points adjusted upward:': 0.1835,
#   '% Series with improved accuracy:': array([0.2317, 0.2561]),
#   '% Series with reduced accuracy:': array([0.7683, 0.7439]),
#   'Original Mean Absolute Error Upward Adjusted:': 119.8891,
#   'Original Mean Absolute Error Downward Adjusted:': 126.975,
#   'Protected Mean Absolute Error Upward Adjusted:': 135.4142,
#   'Protected Mean Absolute Error Downward Adjusted:': 321.2075},
#  'h=1, Bottom 0.1': {'Mean Accuracies': array([64.9424, 64.9424]),
#   'Protected Mean Accuracies:': array([74.5246, 74.5246]),
#   '% Change Mean accuracy:': array([-0.1475, -0.1475]),
#   '% Change Median accuracy:': array([0.0257, 0.0257]),
#   '% Forecasted Points adjusted downward:': 0.3354,
#   '% Forecasted Points adjusted upward:': 0.6646,
#   '% Series with improved accuracy:': array([0.5244, 0.5244]),
#   '% Series with reduced accuracy:': array([0.4756, 0.4756]),
#   'Original Mean Absolute Error Upward Adjusted:': 52.3532,
#   'Original Mean Absolute Error Downward Adjusted:': 89.8919,
#   'Protected Mean Absolute Error Upward Adjusted:': 66.377,
#   'Protected Mean Absolute Error Downward Adjusted:': 90.6717},
#  'h=20, Bottom 0.1': {'Mean Accuracies': array([125.6744, 149.4553]),
#   'Protected Mean Accuracies:': array([134.3823, 156.0847]),
#   '% Change Mean accuracy:': array([-0.0693, -0.0444]),
#   '% Change Median accuracy:': array([0.0702, 0.0656]),
#   '% Forecasted Points adjusted downward:': 0.5082,
#   '% Forecasted Points adjusted upward:': 0.4918,
#   '% Series with improved accuracy:': array([0.4329, 0.4878]),
#   '% Series with reduced accuracy:': array([0.5671, 0.5122]),
#   'Original Mean Absolute Error Upward Adjusted:': 133.5749,
#   'Original Mean Absolute Error Downward Adjusted:': 118.0299,
#   'Protected Mean Absolute Error Upward Adjusted:': 155.7016,
#   'Protected Mean Absolute Error Downward Adjusted:': 113.7535},
#  'h=1, Bottom 0.2': {'Mean Accuracies': array([64.9424, 64.9424]),
#   'Protected Mean Accuracies:': array([101.8176, 101.8176]),
#   '% Change Mean accuracy:': array([-0.5678, -0.5678]),
#   '% Change Median accuracy:': array([0.0567, 0.0567]),
#   '% Forecasted Points adjusted downward:': 0.3902,
#   '% Forecasted Points adjusted upward:': 0.6098,
#   '% Series with improved accuracy:': array([0.4756, 0.4756]),
#   '% Series with reduced accuracy:': array([0.5244, 0.5244]),
#   'Original Mean Absolute Error Upward Adjusted:': 76.8403,
#   'Original Mean Absolute Error Downward Adjusted:': 46.3519,
#   'Protected Mean Absolute Error Upward Adjusted:': 132.0664,
#   'Protected Mean Absolute Error Downward Adjusted:': 54.5538},
#  'h=20, Bottom 0.2': {'Mean Accuracies': array([125.6744, 149.4553]),
#   'Protected Mean Accuracies:': array([154.6578, 175.35  ]),
#   '% Change Mean accuracy:': array([-0.2306, -0.1733]),
#   '% Change Median accuracy:': array([0.0356, 0.0528]),
#   '% Forecasted Points adjusted downward:': 0.5826,
#   '% Forecasted Points adjusted upward:': 0.4174,
#   '% Series with improved accuracy:': array([0.4573, 0.4695]),
#   '% Series with reduced accuracy:': array([0.5427, 0.5305]),
#   'Original Mean Absolute Error Upward Adjusted:': 153.1097,
#   'Original Mean Absolute Error Downward Adjusted:': 106.0204,
#   'Protected Mean Absolute Error Upward Adjusted:': 229.1897,
#   'Protected Mean Absolute Error Downward Adjusted:': 101.2646},
#  'h=1, Bottom 0.4': {'Mean Accuracies': array([64.9424, 64.9424]),
#   'Protected Mean Accuracies:': array([161.9462, 161.9462]),
#   '% Change Mean accuracy:': array([-1.4937, -1.4937]),
#   '% Change Median accuracy:': array([-0.0034, -0.0034]),
#   '% Forecasted Points adjusted downward:': 0.4695,
#   '% Forecasted Points adjusted upward:': 0.5305,
#   '% Series with improved accuracy:': array([0.5061, 0.5061]),
#   '% Series with reduced accuracy:': array([0.4939, 0.4939]),
#   'Original Mean Absolute Error Upward Adjusted:': 75.1937,
#   'Original Mean Absolute Error Downward Adjusted:': 53.3597,
#   'Protected Mean Absolute Error Upward Adjusted:': 262.4393,
#   'Protected Mean Absolute Error Downward Adjusted:': 48.402},
#  'h=20, Bottom 0.4': {'Mean Accuracies': array([125.6744, 149.4553]),
#   'Protected Mean Accuracies:': array([213.9549, 233.7575]),
#   '% Change Mean accuracy:': array([-0.7025, -0.5641]),
#   '% Change Median accuracy:': array([-0.0431, -0.0277]),
#   '% Forecasted Points adjusted downward:': 0.6503,
#   '% Forecasted Points adjusted upward:': 0.3497,
#   '% Series with improved accuracy:': array([0.378 , 0.3902]),
#   '% Series with reduced accuracy:': array([0.622 , 0.6098]),
#   'Original Mean Absolute Error Upward Adjusted:': 143.9487,
#   'Original Mean Absolute Error Downward Adjusted:': 115.8476,
#   'Protected Mean Absolute Error Upward Adjusted:': 400.7364,
#   'Protected Mean Absolute Error Downward Adjusted:': 113.5149}}

# %% [markdown]
# ***
# ***

# %% [markdown]
# ## More Complex Model (window length = 40)

# %%
forecaster = lgb.LGBMRegressor()
window_length = 40

# %%
results_dict_40 = {}
fcasts_40 = {}
fcasts_protected_40 = {}
tests = {}
types = ["Top", "Bottom"]
percentages = [0.10, 0.20, 0.40]
horizons = [1, 20]

# %%
for t in types:
    for p in percentages:
        for h in horizons:
            idx = "h="+str(h)+", "+t+" "+str(p)
            results_dict_40[idx], tests[idx], fcasts_40[idx], fcasts_protected_40[idx] = full_coding_analysis(time_series_data=Y,
                                                                                                              forecasting_model=forecaster,
                                                                                                              forecast_horizon=h, 
                                                                                                              coding_type=t, 
                                                                                                              coding_percentage=p, 
                                                                                                              window_length=window_length)

# %%
results_dict_40
# Out:
# {'h=1, Top 0.1': {'Mean Accuracies': array([67.7525, 67.7525]),
#   'Protected Mean Accuracies:': array([111.5692, 111.5692]),
#   '% Change Mean accuracy:': array([-0.6467, -0.6467]),
#   '% Change Median accuracy:': array([-1.4123, -1.4123]),
#   '% Forecasted Points adjusted downward:': 0.75,
#   '% Forecasted Points adjusted upward:': 0.25,
#   '% Series with improved accuracy:': array([0.311, 0.311]),
#   '% Series with reduced accuracy:': array([0.689, 0.689]),
#   'Original Mean Absolute Error Upward Adjusted:': 99.1719,
#   'Original Mean Absolute Error Downward Adjusted:': 57.2793,
#   'Protected Mean Absolute Error Upward Adjusted:': 91.8678,
#   'Protected Mean Absolute Error Downward Adjusted:': 118.1363},
#  'h=20, Top 0.1': {'Mean Accuracies': array([166.4712, 191.1059]),
#   'Protected Mean Accuracies:': array([181.7919, 205.7167]),
#   '% Change Mean accuracy:': array([-0.092 , -0.0765]),
#   '% Change Median accuracy:': array([ 0.0239, -0.005 ]),
#   '% Forecasted Points adjusted downward:': 0.7399,
#   '% Forecasted Points adjusted upward:': 0.2601,
#   '% Series with improved accuracy:': array([0.4024, 0.3902]),
#   '% Series with reduced accuracy:': array([0.5976, 0.6098]),
#   'Original Mean Absolute Error Upward Adjusted:': 206.4786,
#   'Original Mean Absolute Error Downward Adjusted:': 152.4101,
#   'Protected Mean Absolute Error Upward Adjusted:': 211.6805,
#   'Protected Mean Absolute Error Downward Adjusted:': 171.2872},
#  'h=1, Top 0.2': {'Mean Accuracies': array([67.7525, 67.7525]),
#   'Protected Mean Accuracies:': array([158.9554, 158.9554]),
#   '% Change Mean accuracy:': array([-1.3461, -1.3461]),
#   '% Change Median accuracy:': array([-2.7174, -2.7174]),
#   '% Forecasted Points adjusted downward:': 0.7439,
#   '% Forecasted Points adjusted upward:': 0.2561,
#   '% Series with improved accuracy:': array([0.2866, 0.2866]),
#   '% Series with reduced accuracy:': array([0.7134, 0.7134]),
#   'Original Mean Absolute Error Upward Adjusted:': 106.5091,
#   'Original Mean Absolute Error Downward Adjusted:': 54.41,
#   'Protected Mean Absolute Error Upward Adjusted:': 90.9277,
#   'Protected Mean Absolute Error Downward Adjusted:': 182.3748},
#  'h=20, Top 0.2': {'Mean Accuracies': array([166.4712, 191.1059]),
#   'Protected Mean Accuracies:': array([225.0424, 246.5826]),
#   '% Change Mean accuracy:': array([-0.3518, -0.2903]),
#   '% Change Median accuracy:': array([-0.4242, -0.2842]),
#   '% Forecasted Points adjusted downward:': 0.7866,
#   '% Forecasted Points adjusted upward:': 0.2134,
#   '% Series with improved accuracy:': array([0.2866, 0.311 ]),
#   '% Series with reduced accuracy:': array([0.7134, 0.689 ]),
#   'Original Mean Absolute Error Upward Adjusted:': 256.5021,
#   'Original Mean Absolute Error Downward Adjusted:': 142.0442,
#   'Protected Mean Absolute Error Upward Adjusted:': 268.0347,
#   'Protected Mean Absolute Error Downward Adjusted:': 213.3778},
#  'h=1, Top 0.4': {'Mean Accuracies': array([67.7525, 67.7525]),
#   'Protected Mean Accuracies:': array([288.6295, 288.6295]),
#   '% Change Mean accuracy:': array([-3.2601, -3.2601]),
#   '% Change Median accuracy:': array([-5.5027, -5.5027]),
#   '% Forecasted Points adjusted downward:': 0.811,
#   '% Forecasted Points adjusted upward:': 0.189,
#   '% Series with improved accuracy:': array([0.2561, 0.2561]),
#   '% Series with reduced accuracy:': array([0.7439, 0.7439]),
#   'Original Mean Absolute Error Upward Adjusted:': 111.358,
#   'Original Mean Absolute Error Downward Adjusted:': 57.5888,
#   'Protected Mean Absolute Error Upward Adjusted:': 92.5246,
#   'Protected Mean Absolute Error Downward Adjusted:': 334.3382},
#  'h=20, Top 0.4': {'Mean Accuracies': array([166.4712, 191.1059]),
#   'Protected Mean Accuracies:': array([298.4248, 318.6837]),
#   '% Change Mean accuracy:': array([-0.7927, -0.6676]),
#   '% Change Median accuracy:': array([-1.0182, -0.8405]),
#   '% Forecasted Points adjusted downward:': 0.8,
#   '% Forecasted Points adjusted upward:': 0.2,
#   '% Series with improved accuracy:': array([0.2561, 0.2744]),
#   '% Series with reduced accuracy:': array([0.7439, 0.7256]),
#   'Original Mean Absolute Error Upward Adjusted:': 122.9076,
#   'Original Mean Absolute Error Downward Adjusted:': 177.3621,
#   'Protected Mean Absolute Error Upward Adjusted:': 126.7447,
#   'Protected Mean Absolute Error Downward Adjusted:': 341.3448},
#  'h=1, Bottom 0.1': {'Mean Accuracies': array([67.7525, 67.7525]),
#   'Protected Mean Accuracies:': array([77.2173, 77.2173]),
#   '% Change Mean accuracy:': array([-0.1397, -0.1397]),
#   '% Change Median accuracy:': array([0.0176, 0.0176]),
#   '% Forecasted Points adjusted downward:': 0.439,
#   '% Forecasted Points adjusted upward:': 0.561,
#   '% Series with improved accuracy:': array([0.5, 0.5]),
#   '% Series with reduced accuracy:': array([0.5, 0.5]),
#   'Original Mean Absolute Error Upward Adjusted:': 63.1826,
#   'Original Mean Absolute Error Downward Adjusted:': 73.5917,
#   'Protected Mean Absolute Error Upward Adjusted:': 78.3464,
#   'Protected Mean Absolute Error Downward Adjusted:': 75.7746},
#  'h=20, Bottom 0.1': {'Mean Accuracies': array([166.4712, 191.1059]),
#   'Protected Mean Accuracies:': array([160.102 , 183.4323]),
#   '% Change Mean accuracy:': array([0.0383, 0.0402]),
#   '% Change Median accuracy:': array([0.0031, 0.0021]),
#   '% Forecasted Points adjusted downward:': 0.5537,
#   '% Forecasted Points adjusted upward:': 0.4463,
#   '% Series with improved accuracy:': array([0.4573, 0.4756]),
#   '% Series with reduced accuracy:': array([0.5427, 0.5244]),
#   'Original Mean Absolute Error Upward Adjusted:': 153.8994,
#   'Original Mean Absolute Error Downward Adjusted:': 176.6062,
#   'Protected Mean Absolute Error Upward Adjusted:': 175.1328,
#   'Protected Mean Absolute Error Downward Adjusted:': 147.9846},
#  'h=1, Bottom 0.2': {'Mean Accuracies': array([67.7525, 67.7525]),
#   'Protected Mean Accuracies:': array([97.7945, 97.7945]),
#   '% Change Mean accuracy:': array([-0.4434, -0.4434]),
#   '% Change Median accuracy:': array([0.0014, 0.0014]),
#   '% Forecasted Points adjusted downward:': 0.439,
#   '% Forecasted Points adjusted upward:': 0.561,
#   '% Series with improved accuracy:': array([0.4634, 0.4634]),
#   '% Series with reduced accuracy:': array([0.5366, 0.5366]),
#   'Original Mean Absolute Error Upward Adjusted:': 79.4595,
#   'Original Mean Absolute Error Downward Adjusted:': 52.7935,
#   'Protected Mean Absolute Error Upward Adjusted:': 131.5658,
#   'Protected Mean Absolute Error Downward Adjusted:': 54.6423},
#  'h=20, Bottom 0.2': {'Mean Accuracies': array([166.4712, 191.1059]),
#   'Protected Mean Accuracies:': array([187.7031, 209.7368]),
#   '% Change Mean accuracy:': array([-0.1275, -0.0975]),
#   '% Change Median accuracy:': array([-0.0144,  0.0198]),
#   '% Forecasted Points adjusted downward:': 0.571,
#   '% Forecasted Points adjusted upward:': 0.429,
#   '% Series with improved accuracy:': array([0.439 , 0.4451]),
#   '% Series with reduced accuracy:': array([0.561 , 0.5549]),
#   'Original Mean Absolute Error Upward Adjusted:': 203.1551,
#   'Original Mean Absolute Error Downward Adjusted:': 138.9143,
#   'Protected Mean Absolute Error Upward Adjusted:': 277.7848,
#   'Protected Mean Absolute Error Downward Adjusted:': 120.0336},
#  'h=1, Bottom 0.4': {'Mean Accuracies': array([67.7525, 67.7525]),
#   'Protected Mean Accuracies:': array([162.712, 162.712]),
#   '% Change Mean accuracy:': array([-1.4016, -1.4016]),
#   '% Change Median accuracy:': array([-0.1914, -0.1914]),
#   '% Forecasted Points adjusted downward:': 0.5,
#   '% Forecasted Points adjusted upward:': 0.5,
#   '% Series with improved accuracy:': array([0.4878, 0.4878]),
#   '% Series with reduced accuracy:': array([0.5122, 0.5122]),
#   'Original Mean Absolute Error Upward Adjusted:': 83.1007,
#   'Original Mean Absolute Error Downward Adjusted:': 52.4043,
#   'Protected Mean Absolute Error Upward Adjusted:': 278.9892,
#   'Protected Mean Absolute Error Downward Adjusted:': 46.4347},
#  'h=20, Bottom 0.4': {'Mean Accuracies': array([166.4712, 191.1059]),
#   'Protected Mean Accuracies:': array([236.156 , 257.7626]),
#   '% Change Mean accuracy:': array([-0.4186, -0.3488]),
#   '% Change Median accuracy:': array([-0.0931, -0.0762]),
#   '% Forecasted Points adjusted downward:': 0.696,
#   '% Forecasted Points adjusted upward:': 0.304,
#   '% Series with improved accuracy:': array([0.3659, 0.3659]),
#   '% Series with reduced accuracy:': array([0.6341, 0.6341]),
#   'Original Mean Absolute Error Upward Adjusted:': 211.2475,
#   'Original Mean Absolute Error Downward Adjusted:': 146.9172,
#   'Protected Mean Absolute Error Upward Adjusted:': 465.2195,
#   'Protected Mean Absolute Error Downward Adjusted:': 136.1226}}
